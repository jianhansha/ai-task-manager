# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath("..")) 
from agents.task_parse_agent import TaskParseAgent
from db.taskmanager import TaskManager
from agents.intent_router_agent import IntentRouter
task_mgr = TaskManager()
router = IntentRouter()

print("Hi! Welcome to the AI Task Manager")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 from agents.task_parse_agent import TaskParseAgent
#       7 from db.taskmanager import TaskManager
# ----> 8 from agents.intent_router_agent import IntentRouter
#       9 task_mgr = TaskManager()
#      10 router = IntentRouter()
#
# File ~/Desktop/Code/ai-task-manager/agents/intent_router_agent.py:2
#       1 from langchain_core.prompts import PromptTemplate
# ----> 2 from langchain_core.output_parsers import StructuredOutputParser, ResponseSchema
#       3 from langchain_core.runnables import RunnableSequence
#       4 from langchain.chains.router import LLMRouterChain
#
# ImportError: cannot import name 'StructuredOutputParser' from 'langchain_core.output_parsers' (/Users/jianputhucheary/Desktop/Code/ai-task-manager/.venv/lib/python3.11/site-packages/langchain_core/output_parsers/__init__.py)

# %%
router.run("Please remind me to call my mum on Friday. It's very urgent")

# %%
user_input = input("How can I help you today?")
response = parse_bot.parse_task(user_input)
response

# %%
task_mgr.add_task(response)

# %%
print(task_mgr.get_all_tasks())

# %%
task_data = task_mgr.get_all_tasks()

# %%
task_dicts = [
    {
        "id": task.id,
        "task_description": task.task_description,
        "task_category": task.task_category,
        "due_date": task.due_date,
        "priority": task.priority,
        "tags": task.tags,
        "is_recurring": task.is_recurring,
        "created_at": task.created_at,
    }
    for task in task_data
]
df = pd.DataFrame(task_dicts)

# %%
df
